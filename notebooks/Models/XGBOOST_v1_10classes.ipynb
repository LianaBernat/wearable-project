# %% [markdown]
# # XGBOOST

# %%
# !pip install xgboost==1.7.6
# Out:
# Requirement already satisfied: xgboost==1.7.6 in /usr/local/lib/python3.12/dist-packages (1.7.6)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from xgboost==1.7.6) (2.0.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from xgboost==1.7.6) (1.16.3)

# %%
import numpy as np
import pandas as pd

import seaborn as sns
import matplotlib.pyplot as plt
from xgboost import XGBClassifier

from sklearn.model_selection import train_test_split
from sklearn.utils.class_weight import compute_class_weight
from sklearn.metrics import f1_score, accuracy_score, confusion_matrix

# %%
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# %% [markdown]
# ## Importando a base de dados

# %%
#df_all = pd.read_parquet("../../data/data_processed/participants/Participants_all.parquet")

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df_all = pd.read_parquet("/content/drive/MyDrive/capture24/Participants_all.parquet")

# %%
df_all.head()
# Out:
#     pid        window_start          window_end  n_samples  duration_seconds  \
# 0  P001 2016-11-13 02:18:00 2016-11-13 02:18:05        500              4.99
# 1  P001 2016-11-13 02:18:05 2016-11-13 02:18:10        500              4.99
# 2  P001 2016-11-13 02:18:10 2016-11-13 02:18:15        500              4.99
# 3  P001 2016-11-13 02:18:15 2016-11-13 02:18:20        500              4.99
# 4  P001 2016-11-13 02:18:20 2016-11-13 02:18:25        500              4.99
#
#    sex  age_group label:Walmsley2020  label:Walmsley2020_enc  \
# 0    1          2              sleep                       3
# 1    1          2              sleep                       3
# 2    1          2              sleep                       3
# 3    1          2              sleep                       3
# 4    1          2              sleep                       3
#
#   label:WillettsSpecific2018  label:WillettsSpecific2018_enc  \
# 0                      sleep                               5
# 1                      sleep                               5
# 2                      sleep                               5
# 3                      sleep                               5
# 4                      sleep                               5
#
#   label:WillettsMET2018  label:WillettsMET2018_enc    x_mean     x_std  \
# 0                 sleep                          5 -0.468161  0.004565
# 1                 sleep                          5 -0.470069  0.006437
# 2                 sleep                          5 -0.469694  0.006162
# 3                 sleep                          5 -0.469287  0.005821
# 4                 sleep                          5 -0.470820  0.006896
#
#       x_min    x_max    y_mean     y_std     y_min     y_max    z_mean  \
# 0 -0.482334 -0.46669 -0.537512  0.006892 -0.548902 -0.533341  0.657518
# 1 -0.482334 -0.46669 -0.537045  0.006771 -0.548902 -0.517780  0.657702
# 2 -0.482334 -0.46669 -0.537947  0.007104 -0.548902 -0.533341  0.657764
# 3 -0.482334 -0.46669 -0.537512  0.006962 -0.548902 -0.517780  0.657733
# 4 -0.482334 -0.46669 -0.535333  0.005291 -0.548902 -0.517780  0.658226
#
#       z_std     z_min     z_max  energy_x  energy_y  energy_z  energy_total  \
# 0  0.003960  0.643077  0.673867  0.219195  0.288966  0.432345      0.940507
# 1  0.003627  0.643077  0.673867  0.221007  0.288463  0.432585      0.942055
# 2  0.003369  0.643077  0.673867  0.220650  0.289438  0.432665      0.942753
# 3  0.003567  0.643077  0.673867  0.220264  0.288967  0.432626      0.941857
# 4  0.002743  0.643077  0.673867  0.221719  0.286609  0.433269      0.941597
#
#    magnitude_mean   corr_xy   corr_xz   corr_yz  fft_dom_freq  fft_peak_power  \
# 0        0.969787 -0.148480 -0.077644  0.275487           0.0             0.0
# 1        0.970582 -0.108382 -0.028882  0.137541           0.0             0.0
# 2        0.970944 -0.260468 -0.079268  0.204062           0.0             0.0
# 3        0.970483 -0.243211 -0.092415  0.223157           0.0             0.0
# 4        0.970350 -0.225457 -0.079250  0.230302           0.0             0.0
#
#    hour_sin  hour_cos
# 0  0.566406  0.824126
# 1  0.566706  0.823920
# 2  0.567005  0.823714
# 3  0.567305  0.823508
# 4  0.567604  0.823302

# %%
#features baseadas em aceleração
features_acc = [
    'x_mean', 'x_std','x_min', 'x_max',
    'y_mean', 'y_std', 'y_min', 'y_max',
    'z_mean','z_std', 'z_min', 'z_max',
    'energy_x', 'energy_y', 'energy_z','energy_total',
    'magnitude_mean', 'corr_xy', 'corr_xz', 'corr_yz',
    'fft_dom_freq', 'fft_peak_power'
]

#features de contexto, não baseadas em aceleração.
features_cont = ['sex', 'age_group', 'hour_sin', 'hour_cos']

#colunas que contem nas e precisam ser zeradas
cols_corr = ["corr_xy", "corr_xz", "corr_yz"]
df_all[cols_corr] = df_all[cols_corr].fillna(0)

#Participante para teste e target
PID_TEST = "P043"
TARGET = "label:WillettsSpecific2018"
TARGET_enc = "label:WillettsSpecific2018_enc"
n_class = df_all[TARGET].nunique()

TREE_METHOD = "gpu_hist" #gpu_hist se estiver na GPU ou hist se não estiver

# %%
label2enc = (
    df_all[[TARGET,TARGET_enc]]
    .drop_duplicates()
    .set_index(TARGET)[TARGET_enc]
    .sort_index()
    .to_dict()
)

# %%
enc2label = {
    v: k for k, v in label2enc.items()
}

# %%
df_all_train = df_all[df_all["pid"] != PID_TEST].reset_index(drop=True)
df_all_test  = df_all[df_all["pid"] == PID_TEST].reset_index(drop=True)

y_train = df_all_train[TARGET_enc].astype(int)
y_test  = df_all_test[TARGET_enc].astype(int)

X_train_v1 = df_all_train[features_acc].astype("float32")
X_test_v1  = df_all_test[features_acc].astype("float32")

# %% [markdown]
# # Subamostra para tuning

# %%
N_TUNE = 200_000  # ajuste se quiser maior/menor

frac = min(1.0, N_TUNE / len(X_train_v1))

X_tune, _, y_tune, _ = train_test_split(
    X_train_v1,
    y_train,
    train_size=frac,
    stratify=y_train,
    random_state=42
)

len(X_tune), len(y_tune)
# Out:
# (200000, 200000)

# %%
X_tune_train, X_tune_val, y_tune_train, y_tune_val = train_test_split(
    X_tune,
    y_tune,
    test_size=0.2,
    stratify=y_tune,
    random_state=42
)

# %% [markdown]
# ## Pesos de classe → sample_weight

# %%
classes = np.unique(y_train)
class_weights_arr = compute_class_weight(
    class_weight="balanced",
    classes=classes,
    y=y_train
)
class_weight_dict = dict(zip(classes, class_weights_arr))
class_weight_dict
# Out:
# {np.int64(0): np.float64(10.400329564179783),
#  np.int64(1): np.float64(1.4395573627376186),
#  np.int64(2): np.float64(9.137606709600119),
#  np.int64(3): np.float64(2.400716140709845),
#  np.int64(4): np.float64(0.2787789710323946),
#  np.int64(5): np.float64(0.2707976778042112),
#  np.int64(6): np.float64(18.48842424242424),
#  np.int64(7): np.float64(3.1197443327083687),
#  np.int64(8): np.float64(2.6506893355731913),
#  np.int64(9): np.float64(1.5350167728950017)}

# %%
# vetor de pesos por amostra no tuning
sample_weight_tune = y_tune_train.map(class_weight_dict).values
sample_weight_val  = y_tune_val.map(class_weight_dict).values

# %% [markdown]
# ## TUNING NA SUBAMOSTRA

# %%
param_grid = [
    {"n_estimators": 300, "max_depth": 5, "learning_rate": 0.1,  "subsample": 0.8, "colsample_bytree": 0.8},
    {"n_estimators": 500, "max_depth": 5, "learning_rate": 0.1,  "subsample": 0.8, "colsample_bytree": 0.8},
    {"n_estimators": 300, "max_depth": 7, "learning_rate": 0.05, "subsample": 0.9, "colsample_bytree": 0.9},
    {"n_estimators": 500, "max_depth": 7, "learning_rate": 0.05, "subsample": 0.9, "colsample_bytree": 0.9},
]

# %%
best_params = None
best_f1 = -np.inf

for params in param_grid:
    print("\nTestando params:", params)

    model_xgb = XGBClassifier(
        objective="multi:softprob",
        num_class=n_class,
        tree_method=TREE_METHOD,
        eval_metric="mlogloss",
        early_stopping_rounds=20,
        **params,
        n_jobs=-1,
    )

    model_xgb.fit(
        X_tune_train,
        y_tune_train,
        sample_weight=sample_weight_tune,
        eval_set=[(X_tune_val, y_tune_val)],
        sample_weight_eval_set=[sample_weight_val],
        verbose=False,
    )

    # Previsão na validação
    y_val_pred = model_xgb.predict(X_tune_val)
    macro_f1_val = f1_score(y_tune_val, y_val_pred, average="macro")

    print(f"Macro F1 (val): {macro_f1_val:.4f}")

    if macro_f1_val > best_f1:
        best_f1 = macro_f1_val
        best_params = params

print("\nMelhores params:", best_params)
print("Melhor Macro F1 (val):", best_f1)
# Out:
# Testando params: {'n_estimators': 300, 'max_depth': 5, 'learning_rate': 0.1, 'subsample': 0.8, 'colsample_bytree': 0.8}
# Macro F1 (val): 0.4489
#
# Testando params: {'n_estimators': 500, 'max_depth': 5, 'learning_rate': 0.1, 'subsample': 0.8, 'colsample_bytree': 0.8}
# Macro F1 (val): 0.4511
#
# Testando params: {'n_estimators': 300, 'max_depth': 7, 'learning_rate': 0.05, 'subsample': 0.9, 'colsample_bytree': 0.9}
# Macro F1 (val): 0.4632
#
# Testando params: {'n_estimators': 500, 'max_depth': 7, 'learning_rate': 0.05, 'subsample': 0.9, 'colsample_bytree': 0.9}
# Macro F1 (val): 0.4666
#
# Melhores params: {'n_estimators': 500, 'max_depth': 7, 'learning_rate': 0.05, 'subsample': 0.9, 'colsample_bytree': 0.9}
# Melhor Macro F1 (val): 0.46658134980387056

# %% [markdown]
# ## Treinar o XGBOOST

# %%
sample_weight_full = y_train.map(class_weight_dict).values

# %%
X_train_full, X_val_full, y_train_full, y_val_full = train_test_split(
    X_train_v1,
    y_train,
    test_size=0.1,
    stratify=y_train,
    random_state=42
)

sw_train_full = y_train_full.map(class_weight_dict).values
sw_val_full   = y_val_full.map(class_weight_dict).values

# %%
model_xgb_final = XGBClassifier(
    objective="multi:softprob",
    num_class=n_class,
    tree_method=TREE_METHOD,
    eval_metric="mlogloss",
    **best_params,
    n_jobs=-1,
    early_stopping_rounds=30
)

model_xgb_final.fit(
    X_train_full,
    y_train_full,
    sample_weight=sw_train_full,
    eval_set=[(X_val_full, y_val_full)],
    sample_weight_eval_set=[sw_val_full],
    verbose=True
)
# Out:
# [0]	validation_0-mlogloss:2.23875
# [1]	validation_0-mlogloss:2.18419
# [2]	validation_0-mlogloss:2.13661
# [3]	validation_0-mlogloss:2.09417
# [4]	validation_0-mlogloss:2.05574
# [5]	validation_0-mlogloss:2.02146
# [6]	validation_0-mlogloss:1.98940
# [7]	validation_0-mlogloss:1.95993
# [8]	validation_0-mlogloss:1.93224
# [9]	validation_0-mlogloss:1.90654
# [10]	validation_0-mlogloss:1.88272
# [11]	validation_0-mlogloss:1.86053
# [12]	validation_0-mlogloss:1.83957
# [13]	validation_0-mlogloss:1.82010
# [14]	validation_0-mlogloss:1.80147
# [15]	validation_0-mlogloss:1.78396
# [16]	validation_0-mlogloss:1.76723
# [17]	validation_0-mlogloss:1.75124
# [18]	validation_0-mlogloss:1.73633
# [19]	validation_0-mlogloss:1.72226
# [20]	validation_0-mlogloss:1.70828
# [21]	validation_0-mlogloss:1.69525
# [22]	validation_0-mlogloss:1.68289
# [23]	validation_0-mlogloss:1.67096
# [24]	validation_0-mlogloss:1.65952
# [25]	validation_0-mlogloss:1.64849
# [26]	validation_0-mlogloss:1.63806
# [27]	validation_0-mlogloss:1.62801
# [28]	validation_0-mlogloss:1.61842
# [29]	validation_0-mlogloss:1.60931
# [30]	validation_0-mlogloss:1.60047
# [31]	validation_0-mlogloss:1.59209
# [32]	validation_0-mlogloss:1.58433
# [33]	validation_0-mlogloss:1.57670
# [34]	validation_0-mlogloss:1.56920
# [35]	validation_0-mlogloss:1.56188
# [36]	validation_0-mlogloss:1.55510
# [37]	validation_0-mlogloss:1.54855
# [38]	validation_0-mlogloss:1.54212
# [39]	validation_0-mlogloss:1.53588
# [40]	validation_0-mlogloss:1.53007
# [41]	validation_0-mlogloss:1.52437
# [42]	validation_0-mlogloss:1.51907
# [43]	validation_0-mlogloss:1.51395
# [44]	validation_0-mlogloss:1.50876
# [45]	validation_0-mlogloss:1.50387
# [46]	validation_0-mlogloss:1.49907
# [47]	validation_0-mlogloss:1.49442
# [48]	validation_0-mlogloss:1.48972
# [49]	validation_0-mlogloss:1.48506
# [50]	validation_0-mlogloss:1.48089
# [51]	validation_0-mlogloss:1.47676
# [52]	validation_0-mlogloss:1.47270
# [53]	validation_0-mlogloss:1.46871
# [54]	validation_0-mlogloss:1.46504
# [55]	validation_0-mlogloss:1.46162
# [56]	validation_0-mlogloss:1.45822
# [57]	validation_0-mlogloss:1.45503
# [58]	validation_0-mlogloss:1.45164
# [59]	validation_0-mlogloss:1.44838
# [60]	validation_0-mlogloss:1.44529
# [61]	validation_0-mlogloss:1.44219
# [62]	validation_0-mlogloss:1.43915
# [63]	validation_0-mlogloss:1.43604
# [64]	validation_0-mlogloss:1.43292
# [65]	validation_0-mlogloss:1.43006
# [66]	validation_0-mlogloss:1.42742
# [67]	validation_0-mlogloss:1.42481
# [68]	validation_0-mlogloss:1.42214
# [69]	validation_0-mlogloss:1.41982
# [70]	validation_0-mlogloss:1.41743
# [71]	validation_0-mlogloss:1.41514
# [72]	validation_0-mlogloss:1.41292
# [73]	validation_0-mlogloss:1.41046
# [74]	validation_0-mlogloss:1.40807
# [75]	validation_0-mlogloss:1.40577
# [76]	validation_0-mlogloss:1.40370
# [77]	validation_0-mlogloss:1.40173
# [78]	validation_0-mlogloss:1.39959
# [79]	validation_0-mlogloss:1.39749
# [80]	validation_0-mlogloss:1.39546
# [81]	validation_0-mlogloss:1.39365
# [82]	validation_0-mlogloss:1.39161
# [83]	validation_0-mlogloss:1.38955
# [84]	validation_0-mlogloss:1.38759
# [85]	validation_0-mlogloss:1.38589
# [86]	validation_0-mlogloss:1.38431
# [87]	validation_0-mlogloss:1.38277
# [88]	validation_0-mlogloss:1.38118
# [89]	validation_0-mlogloss:1.37963
# [90]	validation_0-mlogloss:1.37782
# [91]	validation_0-mlogloss:1.37622
# [92]	validation_0-mlogloss:1.37445
# [93]	validation_0-mlogloss:1.37303
# [94]	validation_0-mlogloss:1.37145
# [95]	validation_0-mlogloss:1.36991
# [96]	validation_0-mlogloss:1.36834
# [97]	validation_0-mlogloss:1.36692
# [98]	validation_0-mlogloss:1.36555
# [99]	validation_0-mlogloss:1.36431
# [100]	validation_0-mlogloss:1.36287
# [101]	validation_0-mlogloss:1.36145
# [102]	validation_0-mlogloss:1.36019
# [103]	validation_0-mlogloss:1.35902
# [104]	validation_0-mlogloss:1.35779
# [105]	validation_0-mlogloss:1.35679
# [106]	validation_0-mlogloss:1.35564
# [107]	validation_0-mlogloss:1.35450
# [108]	validation_0-mlogloss:1.35331
# [109]	validation_0-mlogloss:1.35198
# [110]	validation_0-mlogloss:1.35077
# [111]	validation_0-mlogloss:1.34948
# [112]	validation_0-mlogloss:1.34854
# [113]	validation_0-mlogloss:1.34744
# [114]	validation_0-mlogloss:1.34650
# [115]	validation_0-mlogloss:1.34547
# [116]	validation_0-mlogloss:1.34436
# [117]	validation_0-mlogloss:1.34342
# [118]	validation_0-mlogloss:1.34252
# [119]	validation_0-mlogloss:1.34166
# [120]	validation_0-mlogloss:1.34057
# [121]	validation_0-mlogloss:1.33948
# [122]	validation_0-mlogloss:1.33852
# [123]	validation_0-mlogloss:1.33774
# [124]	validation_0-mlogloss:1.33690
# [125]	validation_0-mlogloss:1.33607
# [126]	validation_0-mlogloss:1.33516
# [127]	validation_0-mlogloss:1.33412
# [128]	validation_0-mlogloss:1.33341
# [129]	validation_0-mlogloss:1.33258
# [130]	validation_0-mlogloss:1.33186
# [131]	validation_0-mlogloss:1.33126
# [132]	validation_0-mlogloss:1.33061
# [133]	validation_0-mlogloss:1.32985
# [134]	validation_0-mlogloss:1.32917
# [135]	validation_0-mlogloss:1.32825
# [136]	validation_0-mlogloss:1.32740
# [137]	validation_0-mlogloss:1.32678
# [138]	validation_0-mlogloss:1.32571
# [139]	validation_0-mlogloss:1.32493
# [140]	validation_0-mlogloss:1.32418
# [141]	validation_0-mlogloss:1.32352
# [142]	validation_0-mlogloss:1.32286
# [143]	validation_0-mlogloss:1.32200
# [144]	validation_0-mlogloss:1.32132
# [145]	validation_0-mlogloss:1.32066
# [146]	validation_0-mlogloss:1.31974
# [147]	validation_0-mlogloss:1.31914
# [148]	validation_0-mlogloss:1.31858
# [149]	validation_0-mlogloss:1.31788
# [150]	validation_0-mlogloss:1.31695
# [151]	validation_0-mlogloss:1.31644
# [152]	validation_0-mlogloss:1.31568
# [153]	validation_0-mlogloss:1.31516
# [154]	validation_0-mlogloss:1.31444
# [155]	validation_0-mlogloss:1.31362
# [156]	validation_0-mlogloss:1.31305
# [157]	validation_0-mlogloss:1.31240
# [158]	validation_0-mlogloss:1.31187
# [159]	validation_0-mlogloss:1.31133
# [160]	validation_0-mlogloss:1.31073
# [161]	validation_0-mlogloss:1.31017
# [162]	validation_0-mlogloss:1.30978
# [163]	validation_0-mlogloss:1.30940
# [164]	validation_0-mlogloss:1.30893
# [165]	validation_0-mlogloss:1.30833
# [166]	validation_0-mlogloss:1.30787
# [167]	validation_0-mlogloss:1.30721
# [168]	validation_0-mlogloss:1.30662
# [169]	validation_0-mlogloss:1.30605
# [170]	validation_0-mlogloss:1.30567
# [171]	validation_0-mlogloss:1.30517
# [172]	validation_0-mlogloss:1.30446
# [173]	validation_0-mlogloss:1.30388
# [174]	validation_0-mlogloss:1.30340
# [175]	validation_0-mlogloss:1.30283
# [176]	validation_0-mlogloss:1.30240
# [177]	validation_0-mlogloss:1.30192
# [178]	validation_0-mlogloss:1.30141
# [179]	validation_0-mlogloss:1.30095
# [180]	validation_0-mlogloss:1.30064
# [181]	validation_0-mlogloss:1.29996
# [182]	validation_0-mlogloss:1.29938
# [183]	validation_0-mlogloss:1.29883
# [184]	validation_0-mlogloss:1.29838
# [185]	validation_0-mlogloss:1.29781
# [186]	validation_0-mlogloss:1.29734
# [187]	validation_0-mlogloss:1.29682
# [188]	validation_0-mlogloss:1.29631
# [189]	validation_0-mlogloss:1.29593
# [190]	validation_0-mlogloss:1.29544
# [191]	validation_0-mlogloss:1.29501
# [192]	validation_0-mlogloss:1.29440
# [193]	validation_0-mlogloss:1.29395
# [194]	validation_0-mlogloss:1.29357
# [195]	validation_0-mlogloss:1.29303
# [196]	validation_0-mlogloss:1.29250
# [197]	validation_0-mlogloss:1.29214
# [198]	validation_0-mlogloss:1.29160
# [199]	validation_0-mlogloss:1.29113
# [200]	validation_0-mlogloss:1.29079
# [201]	validation_0-mlogloss:1.29036
# [202]	validation_0-mlogloss:1.28997
# [203]	validation_0-mlogloss:1.28956
# [204]	validation_0-mlogloss:1.28920
# [205]	validation_0-mlogloss:1.28888
# [206]	validation_0-mlogloss:1.28844
# [207]	validation_0-mlogloss:1.28796
# [208]	validation_0-mlogloss:1.28751
# [209]	validation_0-mlogloss:1.28706
# [210]	validation_0-mlogloss:1.28649
# [211]	validation_0-mlogloss:1.28612
# [212]	validation_0-mlogloss:1.28562
# [213]	validation_0-mlogloss:1.28531
# [214]	validation_0-mlogloss:1.28486
# [215]	validation_0-mlogloss:1.28452
# [216]	validation_0-mlogloss:1.28398
# [217]	validation_0-mlogloss:1.28339
# [218]	validation_0-mlogloss:1.28305
# [219]	validation_0-mlogloss:1.28272
# [220]	validation_0-mlogloss:1.28232
# [221]	validation_0-mlogloss:1.28205
# [222]	validation_0-mlogloss:1.28170
# [223]	validation_0-mlogloss:1.28139
# [224]	validation_0-mlogloss:1.28110
# [225]	validation_0-mlogloss:1.28063
# [226]	validation_0-mlogloss:1.28021
# [227]	validation_0-mlogloss:1.27977
# [228]	validation_0-mlogloss:1.27940
# [229]	validation_0-mlogloss:1.27902
# [230]	validation_0-mlogloss:1.27857
# [231]	validation_0-mlogloss:1.27811
# [232]	validation_0-mlogloss:1.27762
# [233]	validation_0-mlogloss:1.27718
# [234]	validation_0-mlogloss:1.27682
# [235]	validation_0-mlogloss:1.27651
# [236]	validation_0-mlogloss:1.27608
# [237]	validation_0-mlogloss:1.27572
# [238]	validation_0-mlogloss:1.27524
# [239]	validation_0-mlogloss:1.27489
# [240]	validation_0-mlogloss:1.27432
# [241]	validation_0-mlogloss:1.27399
# [242]	validation_0-mlogloss:1.27361
# [243]	validation_0-mlogloss:1.27333
# [244]	validation_0-mlogloss:1.27303
# [245]	validation_0-mlogloss:1.27249
# [246]	validation_0-mlogloss:1.27211
# [247]	validation_0-mlogloss:1.27186
# [248]	validation_0-mlogloss:1.27143
# [249]	validation_0-mlogloss:1.27110
# [250]	validation_0-mlogloss:1.27055
# [251]	validation_0-mlogloss:1.27024
# [252]	validation_0-mlogloss:1.27007
# [253]	validation_0-mlogloss:1.26972
# [254]	validation_0-mlogloss:1.26942
# [255]	validation_0-mlogloss:1.26904
# [256]	validation_0-mlogloss:1.26873
# [257]	validation_0-mlogloss:1.26839
# [258]	validation_0-mlogloss:1.26810
# [259]	validation_0-mlogloss:1.26767
# [260]	validation_0-mlogloss:1.26729
# [261]	validation_0-mlogloss:1.26700
# [262]	validation_0-mlogloss:1.26666
# [263]	validation_0-mlogloss:1.26632
# [264]	validation_0-mlogloss:1.26604
# [265]	validation_0-mlogloss:1.26560
# [266]	validation_0-mlogloss:1.26540
# [267]	validation_0-mlogloss:1.26506
# [268]	validation_0-mlogloss:1.26476
# [269]	validation_0-mlogloss:1.26436
# [270]	validation_0-mlogloss:1.26404
# [271]	validation_0-mlogloss:1.26371
# [272]	validation_0-mlogloss:1.26343
# [273]	validation_0-mlogloss:1.26308
# [274]	validation_0-mlogloss:1.26277
# [275]	validation_0-mlogloss:1.26248
# [276]	validation_0-mlogloss:1.26217
# [277]	validation_0-mlogloss:1.26184
# [278]	validation_0-mlogloss:1.26150
# [279]	validation_0-mlogloss:1.26111
# [280]	validation_0-mlogloss:1.26071
# [281]	validation_0-mlogloss:1.26035
# [282]	validation_0-mlogloss:1.26006
# [283]	validation_0-mlogloss:1.25976
# [284]	validation_0-mlogloss:1.25948
# [285]	validation_0-mlogloss:1.25928
# [286]	validation_0-mlogloss:1.25897
# [287]	validation_0-mlogloss:1.25864
# [288]	validation_0-mlogloss:1.25836
# [289]	validation_0-mlogloss:1.25809
# [290]	validation_0-mlogloss:1.25776
# [291]	validation_0-mlogloss:1.25746
# [292]	validation_0-mlogloss:1.25711
# [293]	validation_0-mlogloss:1.25679
# [294]	validation_0-mlogloss:1.25651
# [295]	validation_0-mlogloss:1.25628
# [296]	validation_0-mlogloss:1.25594
# [297]	validation_0-mlogloss:1.25567
# [298]	validation_0-mlogloss:1.25540
# [299]	validation_0-mlogloss:1.25507
# [300]	validation_0-mlogloss:1.25479
# [301]	validation_0-mlogloss:1.25453
# [302]	validation_0-mlogloss:1.25428
# [303]	validation_0-mlogloss:1.25397
# [304]	validation_0-mlogloss:1.25373
# [305]	validation_0-mlogloss:1.25345
# [306]	validation_0-mlogloss:1.25318
# [307]	validation_0-mlogloss:1.25293
# [308]	validation_0-mlogloss:1.25267
# [309]	validation_0-mlogloss:1.25242
# [310]	validation_0-mlogloss:1.25221
# [311]	validation_0-mlogloss:1.25197
# [312]	validation_0-mlogloss:1.25165
# [313]	validation_0-mlogloss:1.25136
# [314]	validation_0-mlogloss:1.25098
# [315]	validation_0-mlogloss:1.25077
# [316]	validation_0-mlogloss:1.25045
# [317]	validation_0-mlogloss:1.25019
# [318]	validation_0-mlogloss:1.24997
# [319]	validation_0-mlogloss:1.24961
# [320]	validation_0-mlogloss:1.24936
# [321]	validation_0-mlogloss:1.24910
# [322]	validation_0-mlogloss:1.24875
# [323]	validation_0-mlogloss:1.24845
# [324]	validation_0-mlogloss:1.24828
# [325]	validation_0-mlogloss:1.24803
# [326]	validation_0-mlogloss:1.24772
# [327]	validation_0-mlogloss:1.24743
# [328]	validation_0-mlogloss:1.24717
# [329]	validation_0-mlogloss:1.24702
# [330]	validation_0-mlogloss:1.24679
# [331]	validation_0-mlogloss:1.24657
# [332]	validation_0-mlogloss:1.24636
# [333]	validation_0-mlogloss:1.24617
# [334]	validation_0-mlogloss:1.24591
# [335]	validation_0-mlogloss:1.24571
# [336]	validation_0-mlogloss:1.24550
# [337]	validation_0-mlogloss:1.24524
# [338]	validation_0-mlogloss:1.24501
# [339]	validation_0-mlogloss:1.24484
# [340]	validation_0-mlogloss:1.24460
# [341]	validation_0-mlogloss:1.24441
# [342]	validation_0-mlogloss:1.24406
# [343]	validation_0-mlogloss:1.24382
# [344]	validation_0-mlogloss:1.24360
# [345]	validation_0-mlogloss:1.24328
# [346]	validation_0-mlogloss:1.24311
# [347]	validation_0-mlogloss:1.24286
# [348]	validation_0-mlogloss:1.24263
# [349]	validation_0-mlogloss:1.24233
# [350]	validation_0-mlogloss:1.24213
# [351]	validation_0-mlogloss:1.24195
# [352]	validation_0-mlogloss:1.24172
# [353]	validation_0-mlogloss:1.24146
# [354]	validation_0-mlogloss:1.24120
# [355]	validation_0-mlogloss:1.24095
# [356]	validation_0-mlogloss:1.24070
# [357]	validation_0-mlogloss:1.24045
# [358]	validation_0-mlogloss:1.24027
# [359]	validation_0-mlogloss:1.24013
# [360]	validation_0-mlogloss:1.23996
# [361]	validation_0-mlogloss:1.23981
# [362]	validation_0-mlogloss:1.23958
# [363]	validation_0-mlogloss:1.23931
# [364]	validation_0-mlogloss:1.23907
# [365]	validation_0-mlogloss:1.23883
# [366]	validation_0-mlogloss:1.23855
# [367]	validation_0-mlogloss:1.23833
# [368]	validation_0-mlogloss:1.23813
# [369]	validation_0-mlogloss:1.23786
# [370]	validation_0-mlogloss:1.23763
# [371]	validation_0-mlogloss:1.23743
# [372]	validation_0-mlogloss:1.23718
# [373]	validation_0-mlogloss:1.23696
# [374]	validation_0-mlogloss:1.23679
# [375]	validation_0-mlogloss:1.23663
# [376]	validation_0-mlogloss:1.23635
# [377]	validation_0-mlogloss:1.23616
# [378]	validation_0-mlogloss:1.23599
# [379]	validation_0-mlogloss:1.23579
# [380]	validation_0-mlogloss:1.23558
# [381]	validation_0-mlogloss:1.23538
# [382]	validation_0-mlogloss:1.23511
# [383]	validation_0-mlogloss:1.23498
# [384]	validation_0-mlogloss:1.23466
# [385]	validation_0-mlogloss:1.23441
# [386]	validation_0-mlogloss:1.23420
# [387]	validation_0-mlogloss:1.23408
# [388]	validation_0-mlogloss:1.23391
# [389]	validation_0-mlogloss:1.23373
# [390]	validation_0-mlogloss:1.23348
# [391]	validation_0-mlogloss:1.23326
# [392]	validation_0-mlogloss:1.23300
# [393]	validation_0-mlogloss:1.23282
# [394]	validation_0-mlogloss:1.23266
# [395]	validation_0-mlogloss:1.23247
# [396]	validation_0-mlogloss:1.23226
# [397]	validation_0-mlogloss:1.23211
# [398]	validation_0-mlogloss:1.23194
# [399]	validation_0-mlogloss:1.23168
# [400]	validation_0-mlogloss:1.23152
# [401]	validation_0-mlogloss:1.23127
# [402]	validation_0-mlogloss:1.23100
# [403]	validation_0-mlogloss:1.23084
# [404]	validation_0-mlogloss:1.23068
# [405]	validation_0-mlogloss:1.23043
# [406]	validation_0-mlogloss:1.23026
# [407]	validation_0-mlogloss:1.23008
# [408]	validation_0-mlogloss:1.22987
# [409]	validation_0-mlogloss:1.22968
# [410]	validation_0-mlogloss:1.22950
# [411]	validation_0-mlogloss:1.22926
# [412]	validation_0-mlogloss:1.22906
# [413]	validation_0-mlogloss:1.22890
# [414]	validation_0-mlogloss:1.22878
# [415]	validation_0-mlogloss:1.22856
# [416]	validation_0-mlogloss:1.22839
# [417]	validation_0-mlogloss:1.22818
# [418]	validation_0-mlogloss:1.22801
# [419]	validation_0-mlogloss:1.22783
# [420]	validation_0-mlogloss:1.22766
# [421]	validation_0-mlogloss:1.22748
# [422]	validation_0-mlogloss:1.22724
# [423]	validation_0-mlogloss:1.22712
# [424]	validation_0-mlogloss:1.22697
# [425]	validation_0-mlogloss:1.22679
# [426]	validation_0-mlogloss:1.22663
# [427]	validation_0-mlogloss:1.22637
# [428]	validation_0-mlogloss:1.22616
# [429]	validation_0-mlogloss:1.22597
# [430]	validation_0-mlogloss:1.22575
# [431]	validation_0-mlogloss:1.22556
# [432]	validation_0-mlogloss:1.22539
# [433]	validation_0-mlogloss:1.22519
# [434]	validation_0-mlogloss:1.22504
# [435]	validation_0-mlogloss:1.22490
# [436]	validation_0-mlogloss:1.22464
# [437]	validation_0-mlogloss:1.22444
# [438]	validation_0-mlogloss:1.22425
# [439]	validation_0-mlogloss:1.22404
# [440]	validation_0-mlogloss:1.22392
# [441]	validation_0-mlogloss:1.22373
# [442]	validation_0-mlogloss:1.22351
# [443]	validation_0-mlogloss:1.22330
# [444]	validation_0-mlogloss:1.22314
# [445]	validation_0-mlogloss:1.22301
# [446]	validation_0-mlogloss:1.22282
# [447]	validation_0-mlogloss:1.22268
# [448]	validation_0-mlogloss:1.22257
# [449]	validation_0-mlogloss:1.22240
# [450]	validation_0-mlogloss:1.22222
# [451]	validation_0-mlogloss:1.22202
# [452]	validation_0-mlogloss:1.22182
# [453]	validation_0-mlogloss:1.22169
# [454]	validation_0-mlogloss:1.22147
# [455]	validation_0-mlogloss:1.22129
# [456]	validation_0-mlogloss:1.22109
# [457]	validation_0-mlogloss:1.22096
# [458]	validation_0-mlogloss:1.22076
# [459]	validation_0-mlogloss:1.22061
# [460]	validation_0-mlogloss:1.22049
# [461]	validation_0-mlogloss:1.22029
# [462]	validation_0-mlogloss:1.22011
# [463]	validation_0-mlogloss:1.21996
# [464]	validation_0-mlogloss:1.21981
# [465]	validation_0-mlogloss:1.21965
# [466]	validation_0-mlogloss:1.21946
# [467]	validation_0-mlogloss:1.21924
# [468]	validation_0-mlogloss:1.21905
# [469]	validation_0-mlogloss:1.21890
# [470]	validation_0-mlogloss:1.21871
# [471]	validation_0-mlogloss:1.21859
# [472]	validation_0-mlogloss:1.21843
# [473]	validation_0-mlogloss:1.21828
# [474]	validation_0-mlogloss:1.21812
# [475]	validation_0-mlogloss:1.21791
# [476]	validation_0-mlogloss:1.21767
# [477]	validation_0-mlogloss:1.21744
# [478]	validation_0-mlogloss:1.21728
# [479]	validation_0-mlogloss:1.21708
# [480]	validation_0-mlogloss:1.21686
# [481]	validation_0-mlogloss:1.21671
# [482]	validation_0-mlogloss:1.21654
# [483]	validation_0-mlogloss:1.21644
# [484]	validation_0-mlogloss:1.21626
# [485]	validation_0-mlogloss:1.21613
# [486]	validation_0-mlogloss:1.21599
# [487]	validation_0-mlogloss:1.21585
# [488]	validation_0-mlogloss:1.21572
# [489]	validation_0-mlogloss:1.21557
# [490]	validation_0-mlogloss:1.21540
# [491]	validation_0-mlogloss:1.21526
# [492]	validation_0-mlogloss:1.21511
# [493]	validation_0-mlogloss:1.21487
# [494]	validation_0-mlogloss:1.21477
# [495]	validation_0-mlogloss:1.21460
# [496]	validation_0-mlogloss:1.21444
# [497]	validation_0-mlogloss:1.21427
# [498]	validation_0-mlogloss:1.21412
# [499]	validation_0-mlogloss:1.21394
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/IPython/core/formatters.py in __call__(self, obj, include, exclude)
#     968
#     969             if method is not None:
# --> 970                 return method(include=include, exclude=exclude)
#     971             return None
#     972         else:
#
# /usr/local/lib/python3.12/dist-packages/sklearn/base.py in _repr_mimebundle_(self, **kwargs)
#     467         output = {"text/plain": repr(self)}
#     468         if get_config()["display"] == "diagram":
# --> 469             output["text/html"] = estimator_html_repr(self)
#     470         return output
#     471
#
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/_estimator_html_repr.py in estimator_html_repr(estimator)
#     385     else:
#     386         try:
# --> 387             check_is_fitted(estimator)
#     388             status_label = "<span>Fitted</span>"
#     389             is_fitted_css_class = "fitted"
#
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py in check_is_fitted(estimator, attributes, msg, all_or_any)
#    1749         raise TypeError("%s is not an estimator instance." % (estimator))
#    1750
# -> 1751     tags = get_tags(estimator)
#    1752
#    1753     if not tags.requires_fit and attributes is None:
#
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/_tags.py in get_tags(estimator)
#     428         for klass in reversed(type(estimator).mro()):
#     429             if "__sklearn_tags__" in vars(klass):
# --> 430                 sklearn_tags_provider[klass] = klass.__sklearn_tags__(estimator)  # type: ignore[attr-defined]
#     431                 class_order.append(klass)
#     432             elif "_more_tags" in vars(klass):
#
# /usr/local/lib/python3.12/dist-packages/sklearn/base.py in __sklearn_tags__(self)
#     538
#     539     def __sklearn_tags__(self):
# --> 540         tags = super().__sklearn_tags__()
#     541         tags.estimator_type = "classifier"
#     542         tags.classifier_tags = ClassifierTags()
#
# AttributeError: 'super' object has no attribute '__sklearn_tags__'
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/IPython/core/formatters.py in __call__(self, obj)
#     343             method = get_real_method(obj, self.print_method)
#     344             if method is not None:
# --> 345                 return method()
#     346             return None
#     347         else:
#
# /usr/local/lib/python3.12/dist-packages/sklearn/base.py in _repr_html_inner(self)
#     461         on `get_config()["display"]`.
#     462         """
# --> 463         return estimator_html_repr(self)
#     464
#     465     def _repr_mimebundle_(self, **kwargs):
#
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/_estimator_html_repr.py in estimator_html_repr(estimator)
#     385     else:
#     386         try:
# --> 387             check_is_fitted(estimator)
#     388             status_label = "<span>Fitted</span>"
#     389             is_fitted_css_class = "fitted"
#
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py in check_is_fitted(estimator, attributes, msg, all_or_any)
#    1749         raise TypeError("%s is not an estimator instance." % (estimator))
#    1750
# -> 1751     tags = get_tags(estimator)
#    1752
#    1753     if not tags.requires_fit and attributes is None:
#
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/_tags.py in get_tags(estimator)
#     428         for klass in reversed(type(estimator).mro()):
#     429             if "__sklearn_tags__" in vars(klass):
# --> 430                 sklearn_tags_provider[klass] = klass.__sklearn_tags__(estimator)  # type: ignore[attr-defined]
#     431                 class_order.append(klass)
#     432             elif "_more_tags" in vars(klass):
#
# /usr/local/lib/python3.12/dist-packages/sklearn/base.py in __sklearn_tags__(self)
#     538
#     539     def __sklearn_tags__(self):
# --> 540         tags = super().__sklearn_tags__()
#     541         tags.estimator_type = "classifier"
#     542         tags.classifier_tags = ClassifierTags()
#
# AttributeError: 'super' object has no attribute '__sklearn_tags__'
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=0.9, early_stopping_rounds=30,
#               enable_categorical=False, eval_metric='mlogloss',
#               feature_types=None, gamma=None, gpu_id=None, grow_policy=None,
#               importance_type=None, interaction_constraints=None,
#               learning_rate=0.05, max_bin=None, max_cat_threshold=None,
#               max_cat_to_onehot=None, max_delta_step=None, max_depth=7,
#               max_leaves=None, min_child_weight=None, missing=nan,
#               monotone_constraints=None, n_estimators=500, n_jobs=-1,
#               num_class=10, num_parallel_tree=None, objective='multi:softprob', ...)

# %% [markdown]
# ## Avaliação em P043

# %%
y_pred_test = model_xgb_final.predict(X_test_v1)
test_acc_xgb = accuracy_score(y_test, y_pred_test)
macro_f1_xgb = f1_score(y_test, y_pred_test, average="macro")

print("XGBoost Test accuracy:", test_acc_xgb)
print("XGBoost Macro F1:", macro_f1_xgb)
# Out:
# XGBoost Test accuracy: 0.5469424869288475
# XGBoost Macro F1: 0.3623907747850887

# %%
f1_per_class_xgb = f1_score(y_test, y_pred_test, average=None)
f1_named_xgb = {enc2label[i]: f1_per_class_xgb[i] for i in range(len(f1_per_class_xgb))}

print("F1 por classe (XGBoost):")
for label, v in f1_named_xgb.items():
    print(f"{label:20s} {v:.4f}")

cm_xgb = confusion_matrix(y_test, y_pred_test)
labels_order = [enc2label[i] for i in range(10)]
cm_xgb_df = pd.DataFrame(cm_xgb, index=labels_order, columns=labels_order)
cm_xgb_df
# Out:
# F1 por classe (XGBoost):
# bicycling            0.6205
# household-chores     0.5145
# manual-work          0.0078
# mixed-activity       0.1097
# sitting              0.5598
# sleep                0.9102
# sports               0.1522
# standing             0.2157
# vehicle              0.3123
# walking              0.2212
#                   bicycling  household-chores  manual-work  mixed-activity  \
# bicycling               188                68           25               1
# household-chores         16              1079          174              39
# manual-work               0                 3            2               6
# mixed-activity            2               252           37              80
# sitting                  40               279           36              66
# sleep                     2                30           19               9
# sports                    7               108           31              49
# standing                  7               195           52             146
# vehicle                   1                47            1               3
# walking                   9               375          110              76
#
#                   sitting  sleep  sports  standing  vehicle  walking
# bicycling               2      3       7        16       23        1
# household-chores      105      8      30        91      145       71
# manual-work             0      0       5         2        1        5
# mixed-activity        152      6      19        96      227      113
# sitting              1423    100      22       420      418       26
# sleep                 404   3669      30        46       42        9
# sports                 11      0      65       115      186       61
# standing              114     15      10       234      263       56
# vehicle                36      1       0         8      329        0
# walking                 7      0      33        50       47      149
