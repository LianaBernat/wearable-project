# %%
#Função para empacotar
import pandas as pd
from pathlib import Path

METADATA_PATH = "../data/data_raw/capture24/metadata.csv"
ALL_PARTICIPANT_PATH ="../data/data_processed/participants/"
metadata = pd.read_csv(METADATA_PATH)

def join_participants(metadata, all_participant_path):
    pid = metadata['pid']
    dfs = []

    for id in pid:
        participant_path = f'{ALL_PARTICIPANT_PATH}{id}'
        participant_file = Path(participant_path)/f"{id}_full.parquet"

        df = pd.read_parquet(participant_file)
        dfs.append(df)
        print(f"[OK] {id} successfully joined")

    full_df=pd.concat(dfs, ignore_index=True)
    output_path= Path(all_participant_path)/f"Participants_all.parquet"
    full_df.to_parquet(output_path, index=False)
    return output_path

# %%
output_path= Path(ALL_PARTICIPANT_PATH)/f"Participants_all.parquet"
output_path
# Out:
# PosixPath('../data/data_processed/participants/Participants_all.parquet')

# %%
#teste para dois participantes
metadata_test =metadata.iloc[0:2,:]
metadata_test['pid']
# Out:
# 0    P001
# 1    P002
# Name: pid, dtype: object

# %%
#teste para dois participantes
join_participants(metadata_test, ALL_PARTICIPANT_PATH)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[5], line 2
#       1 #teste para dois participantes
# ----> 2 join_participants(metadata_test, ALL_PARTICIPANT_PATH)
#
# Cell In[2], line 17, in join_participants(metadata, all_participant_path)
#      14 participant_path = f'{ALL_PARTICIPANT_PATH}{id}'
#      15 participant_file = Path(participant_path)/f"{id}_full.parquet"
# ---> 17 df = pd.read_parquet(participant_file)
#      18 dfs.append(df)
#      19 print(f"[OK] {id} successfully joined")
#
# File ~/.pyenv/versions/3.10.6/envs/wearable_project/lib/python3.10/site-packages/pandas/io/parquet.py:669, in read_parquet(path, engine, columns, storage_options, use_nullable_dtypes, dtype_backend, filesystem, filters, **kwargs)
#     666     use_nullable_dtypes = False
#     667 check_dtype_backend(dtype_backend)
# --> 669 return impl.read(
#     670     path,
#     671     columns=columns,
#     672     filters=filters,
#     673     storage_options=storage_options,
#     674     use_nullable_dtypes=use_nullable_dtypes,
#     675     dtype_backend=dtype_backend,
#     676     filesystem=filesystem,
#     677     **kwargs,
#     678 )
#
# File ~/.pyenv/versions/3.10.6/envs/wearable_project/lib/python3.10/site-packages/pandas/io/parquet.py:258, in PyArrowImpl.read(self, path, columns, filters, use_nullable_dtypes, dtype_backend, storage_options, filesystem, **kwargs)
#     256 if manager == "array":
#     257     to_pandas_kwargs["split_blocks"] = True
# --> 258 path_or_handle, handles, filesystem = _get_path_or_handle(
#     259     path,
#     260     filesystem,
#     261     storage_options=storage_options,
#     262     mode="rb",
#     263 )
#     264 try:
#     265     pa_table = self.api.parquet.read_table(
#     266         path_or_handle,
#     267         columns=columns,
#    (...)
#     270         **kwargs,
#     271     )
#
# File ~/.pyenv/versions/3.10.6/envs/wearable_project/lib/python3.10/site-packages/pandas/io/parquet.py:141, in _get_path_or_handle(path, fs, storage_options, mode, is_dir)
#     131 handles = None
#     132 if (
#     133     not fs
#     134     and not is_dir
#    (...)
#     139     # fsspec resources can also point to directories
#     140     # this branch is used for example when reading from non-fsspec URLs
# --> 141     handles = get_handle(
#     142         path_or_handle, mode, is_text=False, storage_options=storage_options
#     143     )
#     144     fs = None
#     145     path_or_handle = handles.handle
#
# File ~/.pyenv/versions/3.10.6/envs/wearable_project/lib/python3.10/site-packages/pandas/io/common.py:882, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#    (...)
#     878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
# --> 882         handle = open(handle, ioargs.mode)
#     883     handles.append(handle)
#     885 # Convert BytesIO or file objects passed with an encoding
#
# FileNotFoundError: [Errno 2] No such file or directory: '../data/data_processed/participants/P001/P001_full.parquet'

# %%
teste = pd.read_parquet('../data/data_processed/participants/Participants_all.parquet')

# %%
teste.head()
# Out:
#     pid        window_start          window_end  n_samples  duration_seconds  \
# 0  P001 2016-11-13 02:18:00 2016-11-13 02:18:05        500              4.99
# 1  P001 2016-11-13 02:18:05 2016-11-13 02:18:10        500              4.99
# 2  P001 2016-11-13 02:18:10 2016-11-13 02:18:15        500              4.99
# 3  P001 2016-11-13 02:18:15 2016-11-13 02:18:20        500              4.99
# 4  P001 2016-11-13 02:18:20 2016-11-13 02:18:25        500              4.99
#
#    sex  age_group label:Walmsley2020  label:Walmsley2020_enc  \
# 0    1          2              sleep                       3
# 1    1          2              sleep                       3
# 2    1          2              sleep                       3
# 3    1          2              sleep                       3
# 4    1          2              sleep                       3
#
#   label:WillettsSpecific2018  ...  energy_z energy_total  magnitude_mean  \
# 0                      sleep  ...  0.432345     0.940507        0.969787
# 1                      sleep  ...  0.432585     0.942055        0.970582
# 2                      sleep  ...  0.432665     0.942753        0.970944
# 3                      sleep  ...  0.432626     0.941857        0.970483
# 4                      sleep  ...  0.433269     0.941597        0.970350
#
#     corr_xy   corr_xz   corr_yz  fft_dom_freq  fft_peak_power  hour_sin  \
# 0 -0.148480 -0.077644  0.275487           0.4        0.000005  0.566406
# 1 -0.108382 -0.028882  0.137541           3.6        0.000008  0.566706
# 2 -0.260468 -0.079268  0.204062           0.4        0.000002  0.567005
# 3 -0.243211 -0.092415  0.223157           0.4        0.000001  0.567305
# 4 -0.225457 -0.079250  0.230302           8.8        0.000002  0.567604
#
#    hour_cos
# 0  0.824126
# 1  0.823920
# 2  0.823714
# 3  0.823508
# 4  0.823302
#
# [5 rows x 37 columns]

# %%
teste.tail()
# Out:
#         pid        window_start          window_end  n_samples  \
# 41148  P002 2016-05-22 02:22:35 2016-05-22 02:22:40        500
# 41149  P002 2016-05-22 02:22:40 2016-05-22 02:22:45        500
# 41150  P002 2016-05-22 02:22:45 2016-05-22 02:22:50        500
# 41151  P002 2016-05-22 02:22:50 2016-05-22 02:22:55        500
# 41152  P002 2016-05-22 02:22:55 2016-05-22 02:23:00        500
#
#        duration_seconds  sex  age_group label:Walmsley2020  \
# 41148              4.99    1          1              sleep
# 41149              4.99    1          1              sleep
# 41150              4.99    1          1              sleep
# 41151              4.99    1          1              sleep
# 41152              4.99    1          1              sleep
#
#        label:Walmsley2020_enc label:WillettsSpecific2018  ...  energy_z  \
# 41148                       3                      sleep  ...  0.392824
# 41149                       3                      sleep  ...  0.393334
# 41150                       3                      sleep  ...  0.393812
# 41151                       3                      sleep  ...  0.394100
# 41152                       3                      sleep  ...  0.394425
#
#       energy_total  magnitude_mean   corr_xy   corr_xz   corr_yz  \
# 41148     1.001840        1.000915 -0.154492 -0.118092  0.213063
# 41149     1.002440        1.001214 -0.151528 -0.098103 -0.001605
# 41150     1.002711        1.001351 -0.058117 -0.071170 -0.009053
# 41151     1.002251        1.001119 -0.106763 -0.108104  0.040443
# 41152     1.003244        1.001615 -0.141075 -0.048431 -0.018019
#
#        fft_dom_freq  fft_peak_power  hour_sin  hour_cos
# 41148           0.4    9.166598e-07  0.582773  0.812635
# 41149           0.6    1.141102e-06  0.583069  0.812423
# 41150          36.0    4.716086e-07  0.583364  0.812211
# 41151           9.6    1.089870e-06  0.583659  0.811999
# 41152           0.6    1.236220e-06  0.583955  0.811786
#
# [5 rows x 37 columns]

# %%
teste.shape
# Out:
# (41153, 37)

# %%
join_participants(metadata, ALL_PARTICIPANT_PATH)
# Out:
# [OK] P001 successfully joined
# [OK] P002 successfully joined
# [OK] P003 successfully joined
# [OK] P004 successfully joined
# [OK] P005 successfully joined
# [OK] P006 successfully joined
# [OK] P007 successfully joined
# [OK] P008 successfully joined
# [OK] P009 successfully joined
# [OK] P010 successfully joined
# [OK] P011 successfully joined
# [OK] P012 successfully joined
# [OK] P013 successfully joined
# [OK] P014 successfully joined
# [OK] P015 successfully joined
# [OK] P016 successfully joined
# [OK] P017 successfully joined
# [OK] P018 successfully joined
# [OK] P019 successfully joined
# [OK] P020 successfully joined
# [OK] P021 successfully joined
# [OK] P022 successfully joined
# [OK] P023 successfully joined
# [OK] P024 successfully joined
# [OK] P025 successfully joined
# [OK] P026 successfully joined
# [OK] P027 successfully joined
# [OK] P028 successfully joined
# [OK] P029 successfully joined
# [OK] P030 successfully joined
# [OK] P031 successfully joined
# [OK] P032 successfully joined
# [OK] P033 successfully joined
# [OK] P034 successfully joined
# [OK] P035 successfully joined
# [OK] P036 successfully joined
# [OK] P037 successfully joined
# [OK] P038 successfully joined
# [OK] P039 successfully joined
# [OK] P040 successfully joined
# [OK] P041 successfully joined
# [OK] P042 successfully joined
# [OK] P043 successfully joined
# [OK] P044 successfully joined
# [OK] P045 successfully joined
# [OK] P046 successfully joined
# [OK] P047 successfully joined
# [OK] P048 successfully joined
# [OK] P049 successfully joined
# [OK] P050 successfully joined
# [OK] P051 successfully joined
# [OK] P052 successfully joined
# [OK] P053 successfully joined
# [OK] P054 successfully joined
# [OK] P055 successfully joined
# [OK] P056 successfully joined
# [OK] P057 successfully joined
# [OK] P058 successfully joined
# [OK] P059 successfully joined
# [OK] P060 successfully joined
# [OK] P061 successfully joined
# [OK] P062 successfully joined
# [OK] P063 successfully joined
# [OK] P064 successfully joined
# [OK] P065 successfully joined
# [OK] P066 successfully joined
# [OK] P067 successfully joined
# [OK] P068 successfully joined
# [OK] P069 successfully joined
# [OK] P070 successfully joined
# [OK] P071 successfully joined
# [OK] P072 successfully joined
# [OK] P073 successfully joined
# [OK] P074 successfully joined
# [OK] P075 successfully joined
# [OK] P076 successfully joined
# [OK] P077 successfully joined
# [OK] P078 successfully joined
# [OK] P079 successfully joined
# [OK] P080 successfully joined
# [OK] P081 successfully joined
# [OK] P082 successfully joined
# [OK] P083 successfully joined
# [OK] P084 successfully joined
# [OK] P085 successfully joined
# [OK] P086 successfully joined
# [OK] P087 successfully joined
# [OK] P088 successfully joined
# [OK] P089 successfully joined
# [OK] P090 successfully joined
# [OK] P091 successfully joined
# [OK] P092 successfully joined
# [OK] P093 successfully joined
# [OK] P094 successfully joined
# [OK] P095 successfully joined
# [OK] P096 successfully joined
# [OK] P097 successfully joined
# [OK] P098 successfully joined
# [OK] P099 successfully joined
# [OK] P100 successfully joined
# [OK] P101 successfully joined
# [OK] P102 successfully joined
# [OK] P103 successfully joined
# [OK] P104 successfully joined
# [OK] P105 successfully joined
# [OK] P106 successfully joined
# [OK] P107 successfully joined
# [OK] P108 successfully joined
# [OK] P109 successfully joined
# [OK] P110 successfully joined
# [OK] P111 successfully joined
# [OK] P112 successfully joined
# [OK] P113 successfully joined
# [OK] P114 successfully joined
# [OK] P115 successfully joined
# [OK] P116 successfully joined
# [OK] P117 successfully joined
# [OK] P118 successfully joined
# [OK] P119 successfully joined
# [OK] P120 successfully joined
# [OK] P121 successfully joined
# [OK] P122 successfully joined
# [OK] P123 successfully joined
# [OK] P124 successfully joined
# [OK] P125 successfully joined
# [OK] P126 successfully joined
# [OK] P127 successfully joined
# [OK] P128 successfully joined
# [OK] P129 successfully joined
# [OK] P130 successfully joined
# [OK] P131 successfully joined
# [OK] P132 successfully joined
# [OK] P133 successfully joined
# [OK] P134 successfully joined
# [OK] P135 successfully joined
# [OK] P136 successfully joined
# [OK] P137 successfully joined
# [OK] P138 successfully joined
# [OK] P139 successfully joined
# [OK] P140 successfully joined
# [OK] P141 successfully joined
# [OK] P142 successfully joined
# [OK] P143 successfully joined
# [OK] P144 successfully joined
# [OK] P145 successfully joined
# [OK] P146 successfully joined
# [OK] P147 successfully joined
# [OK] P148 successfully joined
# [OK] P149 successfully joined
# [OK] P150 successfully joined
# [OK] P151 successfully joined
# PosixPath('../data/data_processed/participants/Participants_all.parquet')

# %%
df_all = pd.read_parquet('../data/data_processed/participants/Participants_all.parquet')

# %%
df_all.head()
# Out:
#     pid        window_start          window_end  n_samples  duration_seconds  \
# 0  P001 2016-11-13 02:18:00 2016-11-13 02:18:05        500              4.99
# 1  P001 2016-11-13 02:18:05 2016-11-13 02:18:10        500              4.99
# 2  P001 2016-11-13 02:18:10 2016-11-13 02:18:15        500              4.99
# 3  P001 2016-11-13 02:18:15 2016-11-13 02:18:20        500              4.99
# 4  P001 2016-11-13 02:18:20 2016-11-13 02:18:25        500              4.99
#
#    sex  age_group label:Walmsley2020  label:Walmsley2020_enc  \
# 0    1          2              sleep                       3
# 1    1          2              sleep                       3
# 2    1          2              sleep                       3
# 3    1          2              sleep                       3
# 4    1          2              sleep                       3
#
#   label:WillettsSpecific2018  ...  energy_z energy_total  magnitude_mean  \
# 0                      sleep  ...  0.432345     0.940507        0.969787
# 1                      sleep  ...  0.432585     0.942055        0.970582
# 2                      sleep  ...  0.432665     0.942753        0.970944
# 3                      sleep  ...  0.432626     0.941857        0.970483
# 4                      sleep  ...  0.433269     0.941597        0.970350
#
#     corr_xy   corr_xz   corr_yz  fft_dom_freq  fft_peak_power  hour_sin  \
# 0 -0.148480 -0.077644  0.275487           0.4        0.000005  0.566406
# 1 -0.108382 -0.028882  0.137541           3.6        0.000008  0.566706
# 2 -0.260468 -0.079268  0.204062           0.4        0.000002  0.567005
# 3 -0.243211 -0.092415  0.223157           0.4        0.000001  0.567305
# 4 -0.225457 -0.079250  0.230302           8.8        0.000002  0.567604
#
#    hour_cos
# 0  0.824126
# 1  0.823920
# 2  0.823714
# 3  0.823508
# 4  0.823302
#
# [5 rows x 37 columns]

# %%
df_all.tail()
# Out:
#           pid        window_start          window_end  n_samples  \
# 1858486  P151 2016-06-12 06:18:35 2016-06-12 06:18:40        500
# 1858487  P151 2016-06-12 06:18:40 2016-06-12 06:18:45        500
# 1858488  P151 2016-06-12 06:18:45 2016-06-12 06:18:50        500
# 1858489  P151 2016-06-12 06:18:50 2016-06-12 06:18:55        500
# 1858490  P151 2016-06-12 06:18:55 2016-06-12 06:19:00        500
#
#          duration_seconds  sex  age_group label:Walmsley2020  \
# 1858486              4.99    1          1              sleep
# 1858487              4.99    1          1              sleep
# 1858488              4.99    1          1              sleep
# 1858489              4.99    1          1              sleep
# 1858490              4.99    1          1              sleep
#
#          label:Walmsley2020_enc label:WillettsSpecific2018  ...  energy_z  \
# 1858486                       3                      sleep  ...  0.694194
# 1858487                       3                      sleep  ...  0.695744
# 1858488                       3                      sleep  ...  0.695316
# 1858489                       3                      sleep  ...  0.694140
# 1858490                       3                      sleep  ...  0.694621
#
#         energy_total  magnitude_mean   corr_xy   corr_xz   corr_yz  \
# 1858486     1.000766        1.000355 -0.003141 -0.028912 -0.063735
# 1858487     1.002404        1.001177 -0.082219  0.048080  0.025580
# 1858488     1.002025        1.000987  0.009205  0.026980 -0.008575
# 1858489     1.001233        1.000589 -0.075245  0.056886 -0.029143
# 1858490     1.001591        1.000769 -0.047205  0.054113 -0.001164
#
#          fft_dom_freq  fft_peak_power  hour_sin  hour_cos
# 1858486           8.8        0.000006  0.996714 -0.080996
# 1858487          28.2        0.000003  0.996685 -0.081359
# 1858488          18.6        0.000003  0.996655 -0.081721
# 1858489          12.0        0.000006  0.996625 -0.082083
# 1858490           6.8        0.000003  0.996596 -0.082446
#
# [5 rows x 37 columns]

# %%
df_all.shape
# Out:
# (1858491, 37)
